# %%
# Importing the dataset
import pandas as pd
import numpy as np

df = pd.read_csv('dataset/diabetes_prediction_dataset.csv')
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %%
# Select features and label
X = df[['age', 'blood_glucose_level']].values
y = df['diabetes'].values

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Mengimpor library Keras dan turunannya
# Sekarang menggunakan TensorFlow 2.0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Inisialisasi ANN
MesinKlasifikasi = Sequential()

# Menambah input layer dan hidden layer pertama
MesinKlasifikasi.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 2))

# Menambah hidden layer kedua
MesinKlasifikasi.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Menambah output layer
MesinKlasifikasi.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Meenjalankan ANN
MesinKlasifikasi.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting ANN ke training set
MesinKlasifikasi.fit(X_train, y_train, batch_size = 10, epochs = 100)

# Memprediksi hasil test set
y_pred = MesinKlasifikasi.predict(X_test)
y_pred = (y_pred > 0.5)

# Membuat confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Epoch 1/100
# 7500/7500 [==============================] - 16s 2ms/step - loss: 0.1946 - accuracy: 0.9426
# Epoch 2/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1659 - accuracy: 0.9472
# Epoch 3/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1621 - accuracy: 0.9474
# Epoch 4/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1611 - accuracy: 0.9474
# Epoch 5/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1609 - accuracy: 0.9474
# Epoch 6/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1608 - accuracy: 0.9474
# Epoch 7/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1608 - accuracy: 0.9474
# Epoch 8/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 9/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 10/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 11/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 12/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 13/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 14/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 15/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 16/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 17/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 18/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 19/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 20/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 21/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 22/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1608 - accuracy: 0.9473
# Epoch 23/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 24/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 25/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1607 - accuracy: 0.9474
# Epoch 26/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 27/100
# 7500/7500 [==============================] - 18s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 28/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 29/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 30/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 31/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 32/100
# 7500/7500 [==============================] - 16s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 33/100
# 7500/7500 [==============================] - 16s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 34/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 35/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 36/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 37/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 38/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 39/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 40/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 41/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 42/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 43/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 44/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 45/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 46/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 47/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 48/100
# 7500/7500 [==============================] - 17s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 49/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 50/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 51/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 52/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 53/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 54/100
# 7500/7500 [==============================] - 13s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 55/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 56/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 57/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 58/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1606 - accuracy: 0.9474
# Epoch 59/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 60/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 61/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 62/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 63/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 64/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 65/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 66/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 67/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 68/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 69/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1603 - accuracy: 0.9474
# Epoch 70/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 71/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 72/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 73/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 74/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 75/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 76/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 77/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 78/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 79/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 80/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 81/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 82/100
# 7500/7500 [==============================] - 17s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 83/100
# 7500/7500 [==============================] - 17s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 84/100
# 7500/7500 [==============================] - 18s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 85/100
# 7500/7500 [==============================] - 16s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 86/100
# 7500/7500 [==============================] - 17s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 87/100
# 7500/7500 [==============================] - 17s 2ms/step - loss: 0.1605 - accuracy: 0.9474
# Epoch 88/100
# 7500/7500 [==============================] - 16s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 89/100
# 7500/7500 [==============================] - 17s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 90/100
# 7500/7500 [==============================] - 17s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 91/100
# 7500/7500 [==============================] - 16s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 92/100
# 7500/7500 [==============================] - 17s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 93/100
# 7500/7500 [==============================] - 16s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 94/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 95/100
# 7500/7500 [==============================] - 16s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 96/100
# 7500/7500 [==============================] - 14s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 97/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 98/100
# 7500/7500 [==============================] - 17s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 99/100
# 7500/7500 [==============================] - 15s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# Epoch 100/100
# 7500/7500 [==============================] - 16s 2ms/step - loss: 0.1604 - accuracy: 0.9474
# 782/782 [==============================] - 2s 2ms/step
# Confusion Matrix:
# [[22895     0]
#  [ 1281   824]]
