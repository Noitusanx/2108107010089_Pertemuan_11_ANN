# %%
# Mengimpor library yang diperlukan
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Mengimpor dataset
dataset = pd.read_csv('dataset/Data_bank_churn.csv')
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
# Mengonversi data kategori jenis kelamin menjadi numerik
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
labelencoder = LabelEncoder()
X[:, 2] = labelencoder.fit_transform(X[:, 2])

# %%
# Membuat dummy variable untuk kolom negara
columnTransformer = ColumnTransformer([('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(columnTransformer.fit_transform(X), dtype = float)
# Menghilangkan 1 dummy variabel di kolom negara
X = X[:, 1:]

# %%
# Membagi data ke test dan training set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Mengimpor library Keras dan turunannya
# Sekarang menggunakan TensorFlow 2.0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Inisialisasi ANN
MesinKlasifikasi = Sequential()
# Menambah input layer dan hidden layer pertama
MesinKlasifikasi.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
# Menambah hidden layer kedua
MesinKlasifikasi.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
# Menambah output layer
MesinKlasifikasi.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
# Meenjalankan ANN
MesinKlasifikasi.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
# Fitting ANN ke training set
MesinKlasifikasi.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Memprediksi hasil test set
y_pred = MesinKlasifikasi.predict(X_test)
y_pred = (y_pred > 0.5)
# Membuat confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 3s 2ms/step - loss: 0.4849 - accuracy: 0.7952
# Epoch 2/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4143 - accuracy: 0.7960
# Epoch 3/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3974 - accuracy: 0.8006
# Epoch 4/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3822 - accuracy: 0.8436
# Epoch 5/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3724 - accuracy: 0.8530
# Epoch 6/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3664 - accuracy: 0.8551
# Epoch 7/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3619 - accuracy: 0.8568
# Epoch 8/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3588 - accuracy: 0.8574
# Epoch 9/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3560 - accuracy: 0.8605
# Epoch 10/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3542 - accuracy: 0.8615
# Epoch 11/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3528 - accuracy: 0.8587
# Epoch 12/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3516 - accuracy: 0.8605
# Epoch 13/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3507 - accuracy: 0.8589
# Epoch 14/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3497 - accuracy: 0.8596
# Epoch 15/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3489 - accuracy: 0.8614
# Epoch 16/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3483 - accuracy: 0.8611
# Epoch 17/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3481 - accuracy: 0.8609
# Epoch 18/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3476 - accuracy: 0.8606
# Epoch 19/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3469 - accuracy: 0.8606
# Epoch 20/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3462 - accuracy: 0.8614
# Epoch 21/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3461 - accuracy: 0.8618
# Epoch 22/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3457 - accuracy: 0.8618
# Epoch 23/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3456 - accuracy: 0.8604
# Epoch 24/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3450 - accuracy: 0.8595
# Epoch 25/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3452 - accuracy: 0.8616
# Epoch 26/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3444 - accuracy: 0.8606
# Epoch 27/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3444 - accuracy: 0.8619
# Epoch 28/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3433 - accuracy: 0.8605
# Epoch 29/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3435 - accuracy: 0.8615
# Epoch 30/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3437 - accuracy: 0.8611
# Epoch 31/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3434 - accuracy: 0.8622
# Epoch 32/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3433 - accuracy: 0.8621
# Epoch 33/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3431 - accuracy: 0.8630
# Epoch 34/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3432 - accuracy: 0.8619
# Epoch 35/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3423 - accuracy: 0.8636
# Epoch 36/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3431 - accuracy: 0.8624
# Epoch 37/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.